# %% [markdown]
# # 3. Applying HMP to real data – cumulative method

# %% [markdown]
# In this tutorial we will apply HMP to real data using the Cumulative Method. We will use the data from application 2 of [this](https://www.sciencedirect.com/science/article/abs/pii/S1053811914002249) paper. For the purpose of this tutorial (i.e. computational load) we will only use the first 5 participants of the data (see the [HMP](https://direct.mit.edu/imag/article/doi/10.1162/imag_a_00400/125469) paper for the method and [https://github.com/GWeindel/man_hmp/tree/main/results/replication/SAT_data](https://github.com/GWeindel/man_hmp/tree/main/results/replication/SAT_data) for the whole data).
#
# In this experiment, participants performed a random-dot motion task. They were asked to indicate the direction of motion of a cloud of moving dots. While a proportion of the dots moved in a target direction, the remainder moved randomly and made the direction discrimination more difficult. Difficulty of the task was calibrated per subject. Prior to each trial, participants received a cue that indicated whether they should respond as quickly as possible or whether they should focus on giving an accurate response: the 'speed' and 'accuracy' conditions. In this tutorial we will ignore the difference between these conditions, but in the next tutorial we will look at how we can take conditions into account in the HMP analysis.

# %% [markdown]
# ## Data preparation

# %% [markdown]
# First, we load the required packages and download the data. Depending on your internet connection this can take some time.

# %%
import os
import hmp

import matplotlib.pyplot as plt
import requests


# Declaring path where the EEG data will be stored
epoch_data_path = os.path.join('sample_data', 'eeg')
os.makedirs(epoch_data_path, exist_ok=True)

# URLs of the first 5 participants in the SAT experiment, navigate the osf folder and adapt those if you want to do this tutorial on other data (e.g. P3, N2pc). You can also change 5 to 25 to do the analysis on the full dataset.
base = "https://files.osf.io/v1/resources/29tgr/providers/github/results/replication/SAT_data/"
file_urls = [base + f"processed_500Hz_{(x+1):04d}_epo.fif" for x in range(5)]

# Download and save each file if not already in folder
for i, url in enumerate(file_urls, start=1):
    file_path = os.path.join(epoch_data_path, f'S{i}_epo.fif')
    if not os.path.exists(file_path):
        response = requests.get(url)
        with open(file_path, 'wb') as f:
            f.write(response.content)

# Recovering individual files and participant names
subj_files = [os.path.join(epoch_data_path, f) for f in os.listdir(epoch_data_path) if f.endswith('.fif')]  # Create a list of files with full paths

# %% [markdown]
# In this case the data have been epoched and preprocessed already, but see the tutorial "Reading your own data" for how to get there with your own dataset.
#
# In the cell below, we read in the MNE epoch files, downsample to 200 Hz and specify the montage that was used for recording.

# %%
preprocessing = dict(sfreq=250) #Downsampling from 500Hz to 250Hz for speed and RAM usage
epoch_data, info = hmp.io.read_mne_epochs(subj_files,
                            montage='biosemi64',
                            preprocessing_kwargs=preprocessing,
                            verbose=False)#Turning verbose off for the documentation but it is recommended to leave it on as some output from MNE might be useful

## The following is just for this tutorial dataset and probably not needed for yours
# The duration (i.e. reaction time) data is in milliseconds and we want it in seconds
epoch_data['RT'] /= 1000
# This dataset is in microV, we want the unit in V
epoch_data *= 1e-6

print(epoch_data)
# Out:
# <xarray.Dataset> Size: 97MB
# Dimensions:    (epoch: 200, channel: 30, sample: 812, recording: 5)
# Coordinates:
#   * epoch      (epoch) int64 2kB 0 1 2 3 4 5 6 7 ... 193 194 195 196 197 198 199
#     stim       (recording, epoch) float64 8kB 2.0 2.0 1.0 2.0 ... 2.0 2.0 2.0
#     resp       (recording, epoch) object 8kB 'resp_right' ... 'resp_right'
#     RT         (recording, epoch) float64 8kB 1.311 1.138 0.934 ... 0.649 0.862
#     cue        (recording, epoch) object 8kB 'SP' 'SP' 'AC' ... 'SP' 'AC' 'AC'
#     movement   (recording, epoch) object 8kB 'stim_right' ... 'stim_right'
#     trigger    (recording, epoch) object 8kB 'SP/stim_right/resp_right' ... '...
#   * channel    (channel) <U3 360B 'Fp1' 'Fp2' 'AFz' 'F7' ... 'CPz' 'CP2' 'CP6'
#   * sample     (sample) int64 6kB -62 -61 -60 -59 -58 ... 745 746 747 748 749
#   * recording  (recording) <U2 40B 'S2' 'S1' 'S5' 'S4' 'S3'
#     subject    (recording) <U2 40B 'S2' 'S1' 'S5' 'S4' 'S3'
# Data variables:
# ...

# %% [markdown]
# As you can see the HMP formatted EEG dataset contains some info on the experiment such as the sampling frequency, the number of trials, the number of participants, and the number of channels. In addition, it contains metadata, such as the RTs per trial.

# %% [markdown]
# At this point we have the epoched EEG data with 30 channels, which we need to crop between stimulus and response and transform to PC space. To this end, we will perform the default serie of preprocessing steps (see tutorial 1 for details on the unfolding of the steps).

# %%
base_data = hmp.basedata.default(
    epoch_data, # The data from the io module
    duration_id='RT', # What coordinate in our data contains the duration we want to model
    min_duration = 0.2, # What minimum response time (in second) is reasonable given the task (e.g. anticipation)
    # Minimum duration dictates the number of event that can fit in the data, see FAQ
    max_duration = 2, # same for maximum duration (e.g. distraction or bug), for speed mostly, also to filter clear outliers
    offsets=0.03, # Adding 30ms before centering event and after duration end to pad for the crosscorrelation, not included in the data afterwards
    # Apply a threshold, i.e. reject trial if the absolute value of an electrode exceeds that value
    reject_amplitude = 1e-4, #Here trials get rejected if an electrode exceeds 100microV, useful in the case of artifacts in the data
    n_comp = .99, # How many PCA component we want to compress the data into, here we take as many as necessary to achieve 99% of explained variance, the more the better
    whiten = True, #All components will have unit variance
    common_variance = True, # All trials will have the same standard deviation
    recording_zscore = True # Zscore the components per recording/participant so that all participant are represented equally by the PCs
)
# Out:
# Found 900 trials with positively defined durations and 20 trials without durations (0 or nan)
#
# Rejection summary:
#  0 trials rejected based on threshold of 0.0001
#  1 trials rejected  based on duration limit of (0.2, 2)
#  0 with duration but without data (nan at time 0)
# 7 components retained, explaining 0.99342% variance

# %% [markdown]
# The selection of principal components is used for computational reasons, a higher number of PCs might give a more accurate solution but also increases RAM usage, and takes more noise into the analysis. The advice is thus to check how much variance is explained by the PCs, and for example take the number of PCs that explains 98% of the variance. If you leave the `n_comp` argument empty, a variance graph will be shown, and you can make a decision based on the graph. Alternatively, it is also possible to use `n_comp` to specify a percentage explained variance, for example `.98`, and it will select the number of components necessary to reach that number.
#
# For the tutorial we use 10 PCs as declared in `n_comp`.

# %%
base_data.data
# Out:
# <xarray.DataArray 'data' (sample: 501, component: 7, trial: 899)> Size: 13MB
# array([[[-0.70229465,  0.7294921 , -0.49047455, ..., -0.19877227,
#          -1.094562  ,  0.38090152],
#         [ 0.20136659,  0.41309223,  0.94946694, ...,  0.10814359,
#           0.64455956, -0.31322414],
#         [-0.5074767 ,  0.49655116, -1.1677204 , ..., -0.7300748 ,
#          -0.5291923 , -0.26784062],
#         ...,
#         [ 0.4207531 , -0.41969505,  0.01174769, ...,  0.6649639 ,
#           0.38757488, -0.824586  ],
#         [ 0.8636544 ,  0.26222262, -0.32202926, ...,  1.0301888 ,
#          -1.4218225 , -1.1297491 ],
#         [-0.03713514, -0.628539  , -0.7263473 , ...,  0.74591297,
#           0.8594799 , -0.76437366]],
#
#        [[-0.7494518 ,  0.8075679 , -0.48771015, ..., -0.4984912 ,
#          -0.5607803 ,  0.4646144 ],
#         [ 0.19172107,  0.42564848,  1.3249574 , ...,  0.5738671 ,
#           0.36856073, -0.31116772],
# ...

# %% [markdown]
# Next, we rearrange the data and calculate the cross correlation with the default halfsine pattern (adjusted to sampling frequency). After this operation the data is arranged as 10 PCs x 899 trials (= 162 633 samples): all epochs of all participants were concatenated and are treated by HMP as one big dataset. For a hierarchical (but computationally much more expensive approach, see [this paper](https://www.biorxiv.org/content/10.64898/2025.12.25.696483v1)).

# %%
pattern = hmp.patterns.HalfSine(width=50)
pattern_data = hmp.patterndata.PatternData.from_basedata(base_data, pattern=pattern)
print(pattern_data.cross_corr.shape)
# Out:
# (162633, 7)

# %% [markdown]
# To summarize:
# - `epoch_data` has the original EEG data in EEG space,
# - `base_data` contains the data specifically preprocessed for HMP and projected to PCA space,
# - `pattern_data` contains the cross-correlated `base_data` with the used pattern. This step is optional and we can pass base_data instead
#
# All models can use either `base_data` or `pattern_data`, but it's often a bit more efficient to use `pattern_data`.

# %% [markdown]
# ## Fitting

# %% [markdown]
# As introduced in Tutorial 2, the ```CumulativeEstimation``` method starts by sliding a candidate event from 0 to mean RT. When an event is found – the Expectation Maximization estimation converges – one event is added to the model and the slide continues. This way we can detect new events while accounting for the previous ones. Here we applied this method to the real data of five participants.

# %%
# We initialize a model without specifying a distribution or a pattern to demonstrate the use of base_data for modeling.
model = hmp.models.CumulativeMethod(pattern=pattern)
_, estimates_cumulative = model.fit_transform(pattern_data)
# Out:
# Max event that can be fit given minimum duration of 74 is 6
#   0%|          | 0/26 [00:00<?, ?it/s]
# 1 events found around times [76]
# 2 events found around times [76, 284]
# 3 events found around times [80, 280, 692]

# %%
hmp.visu.plot_topo_timecourse(epoch_data, estimates_cumulative, info)

# %% [markdown]
# The cumulative method returned three events, which fits the results in the paper. We could have also used the eliminative method in combination with Leave-One Out cross validation to arrive at the same result, and to conclude that this solution generalizes best across participants. This approach is illustrated in Tutorial 5.
#
# In the remainder of this tutorial we show how to use the estimated HMP probabilities to inspect topographies of specific events, the time between the most likely time of each event and a fresh way of looking at event related potentials.

# %% [markdown]
# ### Example application 1: looking at individual topographies

# %% [markdown]
# Although HMP models are fitted across all data, it is certainly possible that topographies will look somewhat different when visualized between participants or conditions. Below, we show the third event first for the 5 participants, and then split for right- and left-handed responses.

# %%
# Plotting individual topographies for a specific event across participants
from mne.viz import plot_topomap

# Get event-channel weights for each trial
by_trial_weights = hmp.utils.event_channels(epoch_data, estimates_cumulative, mean=False)

# Plot topographies for each participant for a selected event
fig, axes = plt.subplots(1, 5, dpi=150, figsize=(4, 2))
axes = axes.flatten()
event = 3 # Event index to plot (1-based for display, 0-based for indexing)

# Looking at the topographies of the 5 first participants
for i, recording in enumerate(epoch_data.recording[:5]):
    ax = axes[i]
    # Average across epochs for the selected event and participant
    topo = by_trial_weights.sel(event=event-1, recording=recording).mean('epoch')
    plot_topomap(
        topo,
        info,
        sensors=False,
        cmap='Spectral_r',
        res=100,
        show=False,
        axes=ax,
        contours=6
    )
    ax.set_title(f'{str(recording.values)[:-4]}')

plt.tight_layout()

# %% [markdown]
# Here you can see differences between participants, but they largely look very similar. We can also split between conditions in the experiment. For example, if we split between right- and left-handed responses, we see clear lateralized patterns for the last event, as one would expect for an event related to a motor action.

# %%
for resp in ['resp_right','resp_left']:
    hmp.visu.plot_model(epoch_data, estimates_cumulative.sel(trial=base_data.data.trial.values[base_data.data.resp==resp]), info, title=resp)

# %% [markdown]
# Zooming in on the last event:

# %%
# Plot topographies for each participant for a selected event
fig, axes = plt.subplots(1, 2, dpi=150, figsize=(2, 2))
axes = axes.flatten()
event = 3 # Event index to plot (1-based for display, 0-based for indexing)

# Looking at the topographies of left and right responses
for i, resp in enumerate(['resp_right','resp_left']):
    ax = axes[i]
    # Average across epochs for the selected event and participant
    topo = by_trial_weights.sel(event=event-1, trial=base_data.data.trial.values[base_data.data.resp==resp]).mean('trial')
    plot_topomap(
        topo,
        info,
        sensors=False,
        cmap='Spectral_r',
        res=100,
        show=False,
        axes=ax,
        contours=6
    )
    ax.set_title(f'{str(resp)}')

plt.tight_layout()

# %% [markdown]
# ### Example application 2: analyzing condition effect on interval between events

# %% [markdown]
# In addition to different topologies, we can also look at different interval lengths between events by condition. In this dataset, it seems obvious that in the 'speed' condition the intervals should be shorter – but a valid question is whether that holds for all intervals or just some. See for an interesting real-world analysis [this paper](https://elifesciences.org/articles/108049), in which we manipulated the length of different cognitive stages independently.
#
# Below, we first calculate the most likely time for each event in each trial.

# %%
# Compute max likely time for each trial and each event
times =  hmp.utils.event_times(estimates_cumulative, duration=True, add_rt=True)

# Turn into dataframe and recover metadata
times = times.unstack().to_dataframe(name='duration').reset_index()
times
# Out:
#       event recording  epoch  stim        resp     RT  cue    movement  \
# 0         0        S2      0   2.0  resp_right  1.311   SP  stim_right
# 1         0        S2      1   2.0  resp_right  1.138   SP  stim_right
# 2         0        S2      2   1.0   resp_left  0.934   AC   stim_left
# 3         0        S2      3   2.0  resp_right  0.593   SP  stim_right
# 4         0        S2      4   1.0   resp_left  0.744   AC   stim_left
# ...     ...       ...    ...   ...         ...    ...  ...         ...
# 3995      3        S3    195   1.0  resp_right  1.763   AC   stim_left
# 3996      3        S3    196   1.0   resp_left  0.676   AC   stim_left
# 3997      3        S3    197   NaN         NaN    NaN  NaN         NaN
# 3998      3        S3    198   2.0  resp_right  0.649   AC  stim_right
# 3999      3        S3    199   2.0  resp_right  0.862   AC  stim_right
#
#                        trigger subject  group  duration
# 0     SP/stim_right/resp_right      S2    0.0      10.0
# ...

# %% [markdown]
# Now we plot the average duration between each successive events for both conditions.

# %%
mean_ac = times[times.cue == 'AC'].groupby(['event']).duration.mean()
mean_sp = times[times.cue == 'SP'].groupby(['event']).duration.mean()

plt.plot(mean_ac.index, mean_ac.values, 'o-', label='AC')
plt.plot(mean_sp.index, mean_sp.values, 'o-', label='SP')
plt.legend()
plt.xlabel('Stage')
plt.ylabel('Duration (ms)')
plt.title('Event durations by condition')
# Out:
# Text(0.5, 1.0, 'Event durations by condition')

# %% [markdown]
# As expected, the stage length in the 'accuracy' condition is longer than in the 'speed' condition, but the effect is limited to time between the 2nd and 3rd event.

# %% [markdown]
# ### Example application 3: Comparing conditions on centered ERPs:

# %% [markdown]
# Because we have access to an estimate of the single-trial time of each event we can look at the event related potential of a specific set of electrodes centered on that event instead of stimulus or response, potentially allowing for analyzing much longer trials than is customary with EEG. Here we centered the ERP on event 2.

# %%
# Plotting centered ERPs for each condition (AC and SP) with confidence intervals (±1 std)
fig, ax = plt.subplots(1,1)

# Get event times (positions not durations) for all events/trials, including stimulus onset
times_position = hmp.utils.event_times(estimates_cumulative, duration=False, mean=False, add_stim=True)

# Define window size in samples
baseline = -.1*epoch_data.sfreq  # 100 ms before event
n_samples = .4*epoch_data.sfreq  # 400 ms window

event = 2 # Event index to center on, 0 is stimulus (thus 1-based)

# Select a subset of channels to analyze (e.g., centroparietal channels)
channel_subset = ['CP1', 'CP2']

for SAT in ["AC","SP"]:
    # Select trials for the current condition and stack recording/epoch as 'trial' for easiness
    subset = hmp.utils.select_coord(epoch_data, SAT, variable="cue")
    # Center activity on the event for selected channels
    centered = hmp.utils.centered_activity(subset, times_position, channel_subset,
        event=event, n_samples=n_samples, baseline=baseline)
    # Average across channels,
    centered = centered.data.unstack().mean('channel')
    # Compute mean and std across participants
    indiv_traces = centered.groupby('recording').mean(dim='epoch')
    mean_tc = indiv_traces.mean('recording')
    std_tc = indiv_traces.std('recording')
    # Plot the timecourse with confidence interval
    ax.plot(centered.sample, mean_tc, label=SAT,)
    ax.fill_between(centered.sample, mean_tc-std_tc, mean_tc+std_tc, alpha=0.2)
ax.set_xlabel(f'Time from Event {event} (ms)')
ax.set_ylabel('Amplitude (V)')
plt.legend(title='Condition')
plt.tight_layout()

# %% [markdown]
# We have now demonstrated three typical analyses that we perform on the results of a model. In the next tutorial, we will look in more detail in how one can deal with multiple conditions – either by modeling them separately or by sharing part of the models.

# %% [markdown]
# ## Fit / transform on separate datasets
#
# In the final part of this tutorial we show the possibility of fitting a model on part of the data, and testing it on another part. Here we will show a split-half analysis (for each subject), while in Tutorial 5 we will take the next step and do leave-one-out cross validation across subjects.
#
# First, we select the data, which is easiest on the `base_data` object.

# %%
import numpy as np

data_firsthalf = base_data.select_coord(value=100, variable='epoch', method=np.less_equal)
data_secondhalf = base_data.select_coord(value=100, variable='epoch', method=np.greater)

# %% [markdown]
# Next, we fit the model on the first half of the data:

# %%
model_firsthalf = hmp.models.EventModel(n_events=3, pattern=pattern)
model_firsthalf.fit(data=data_firsthalf)
# Out:
# Estimating 3 events model

# %% [markdown]
# We can now use this fitted model to transform the same data:

# %%
_, estimates_first = model_firsthalf.transform(data_firsthalf)
hmp.visu.plot_model(epoch_data,estimates_first,info, title = 'Fit first half, transform first half')

# %% [markdown]
# or on the second half of each subjects's data:

# %%
_, estimates_second = model_firsthalf.transform(data_secondhalf)
hmp.visu.plot_model(epoch_data,estimates_second,info, title = 'Fit first half, transform second half')

# %% [markdown]
# So what we did here is estimate the HMP model on the first half of each subject's data, but look at the fit on the second half. In this case, the results are highly similar. We could also look at likelihood, for example, which we will do in Tutorial 5.
